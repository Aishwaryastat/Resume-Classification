# %%
pip install PyPDF2
# Out:
# ...
# WARNING: Ignoring invalid distribution -blib (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -olorama (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oblib (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -blib (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\programdata\anaconda3\lib\site-packages)
# ...

# %%
pip install --upgrade PyPDF2==2.12.1

# %%
pip install python-docx
# Out:
# ...
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184508 sha256=c67eca7974ae1813eab545b41ec9f73eae8abb464477b8855239dc9e7e0704ad
#   Stored in directory: c:\users\pcc\appdata\local\pip\cache\wheels\83\8b\7c\09ae60c42c7ba4ed2dddaf2b8b9186cb105255856d6ed3dba5
# Successfully built python-docx
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -blib (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ygments (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -olorama (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oblib (c:\programdata\anaconda3\lib\site-packages)
# ...

# %%
pip install docx
# Out:
# ...
# WARNING: Ignoring invalid distribution -blib (c:\programdata\anaconda3\lib\site-packages)
# ...
#   Created wheel for docx: filename=docx-0.2.4-py3-none-any.whl size=53924 sha256=412a11224b716bd3d70c19d3699040c2558c185f419df99b072d788cde4d3f1e
#   Stored in directory: c:\users\pcc\appdata\local\pip\cache\wheels\0f\8e\9d\7003eed35a84cf960876aae6bdf60d02041ddfcca66eceee94
# Successfully built docx
# ...
# WARNING: Ignoring invalid distribution -ygments (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -olorama (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oblib (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# ...

# %%
import os
import pandas as pd
from docx import Document
import PyPDF2
import random
# Folder path where resume are stored
resumes_dir = "C:/Users/pcc/Downloads/Resumes-20230330T133835Z-001/Resumes/Resumes/react_dev"

# Define the job role for all resumes
job_role = 'react_dev'
# Empty list to store the resume data
resume_data = []

# Loop through each file in the resumes directory
for filename in os.listdir(resumes_dir):
    file_path = os.path.join(resumes_dir, filename)
    
    # Check if the file is a Microsoft Word document
    if filename.endswith('.docx'):
        document = Document(file_path)
        text = '\n'.join([paragraph.text for paragraph in document.paragraphs])
    
    # Check if the file is a Microsoft Word 97-2003 document
    elif filename.endswith('.doc'):
        document = Document(file_path)
        text = '\n'.join([paragraph.text for paragraph in document.paragraphs])
        
    # Check if the file is a PDF
    elif filename.endswith('.pdf'):
        with open(file_path, 'rb') as f:
            pdf_reader = PyPDF2.PdfReader(f)
            text = ''
            for page_num in range(len(pdf_reader.pages)):
                page = pdf_reader.pages[page_num]
                text += page.extract_text()

    # Add the resume data to the list
    resume_data.append({'text': text, 'job_role': job_role})

# Convert the list of dictionaries to a pandas DataFrame
react_dev = pd.DataFrame(resume_data)

# Print the DataFrame
react_dev
# Out:
#                                                  text   job_role
# 0   Name: Ravali P \n\n                           ...  react_dev
# 1     \nSUSOVAN  BAG   \nSeeking  a  challenging  ...  react_dev
# 2   Kanumuru Deepak Reddy\n\n\n\nCAREER OBJECTIVE:...  react_dev
# 3   HARIPRIYA BATTINA \nExperience as UI Developer...  react_dev
# 4   KAMALAKAR REDDY. A \nLinked In: https://www.li...  react_dev
# 5   \nNaveen Sadhu\n\n\nTitle: software developer\...  react_dev
# 6   \n\n\nPROFILE\nSearching for the opportunity t...  react_dev
# 7    \nPRAGNYA PATTNAIK\n \n \n \n Expertise: \n \...  react_dev
# 8   \n\n 204,Sri geethika prestige,road number 10...  react_dev
# 9   \n\nThirupathamma Balla\n\nSUMMARY:\n\n2.8 yea...  react_dev
# 10  Maryala Vinay Reddy\n\nProfessional Summary:\t...  react_dev
# 11  \nUi-Developer/ React JS Developer \nNAME: KRI...  react_dev
# 12  \nUi-Developer/ React JS Developer \nNAME: KRI...  react_dev
# ...

# %%
react_dev.loc[20]["text"]
# Out:
# '   \nPage | 1  \n Name: M. Prabakaran  \nTitle: UI Developer  \n \nPROFESSIONAL SUMMARY  \n \n● 2.4+ years of Professional IT experience as a software developer having knowledge on different UI based \nApplication.  \n● Hands on experience in HTML, CSS, JS, ReactJS.   \n● Hands on experience in handling UI interaction, Design methodology.  \n● Handling In -App purchase, uploading and maintaining apps in play store.  \n● Hands on experience with customization over base -product depends on  client requirement.  \n● Cohesive team worker, having strong analytical, problem solving and interpersonal skills.  \n \nEDUCATION  \n \n● Completed on 2017 Bachelor of Technology (ECE) , PRIST University, Tamil Nadu.  \n● Completed on 2012 Higher Secondary , Mount Park Hr Sec School , Thiyagadurgam,  Tamil Nadu.  \n● Completed on 2010 SSLC , Krishnasamy Hr Sec School , Cuddalore,  Tamil Nadu.  \n \nSKILLS  \n \nOperating System  Windows, Unix,Mac  \nProgramming Languages  HTML, CSS, JS, React  \nM
# ...

# %%
resumes_dir = "C:/Users/pcc/Downloads/Resumes-20230330T133835Z-001/Resumes/Resumes/SQL Developer Lightning insight"

job_role = 'SQL_Developer'

resume_data = []

for filename in os.listdir(resumes_dir):
    file_path = os.path.join(resumes_dir, filename)

    if filename.endswith('.docx'):
        document = Document(file_path)
        text = '\n'.join([paragraph.text for paragraph in document.paragraphs])

    elif filename.endswith('.doc'):
        document = Document(file_path)
        text = '\n'.join([paragraph.text for paragraph in document.paragraphs])

    elif filename.endswith('.pdf'):
        with open(file_path, 'rb') as f:
            pdf_reader = PyPDF2.PdfReader(f)
            text = ''
            for page_num in range(len(pdf_reader.pages)):
                page = pdf_reader.pages[page_num]
                text += page.extract_text()

    resume_data.append({'text': text, 'job_role': job_role})

sql_dev = pd.DataFrame(resume_data)

sql_dev
# Out:
#                                                  text       job_role
# 0   ANIL KUMAR MADDUKURI  \t\t\nSQL & MSBI Develop...  SQL_Developer
# 1   \nAradhana Tripathi\n\nCurrent Location: Gachi...  SQL_Developer
# 2   BUDDHA VAMSI                                  ...  SQL_Developer
# 3   KAMBALLA PRADEEP                              ...  SQL_Developer
# 4   \n\n\n Hyderabad\n\nNazeer Basha\nSQL and Pow...  SQL_Developer
# 5    \n                                        Res...  SQL_Developer
# 6   SQL DEVELOPER\nName: -   Bandi prem sai\n\n\nW...  SQL_Developer
# 7                                          SQL SER...  SQL_Developer
# 8                                          SQL SER...  SQL_Developer
# 9    RAJU PAVANA KUMARI\n\n\nProfessional Summary:...  SQL_Developer
# 10                                      resume\n\n...  SQL_Developer
# 11  Name: Ramesh\n\nCareer Objective: \n          ...  SQL_Developer
# 12  Career objective\n\t\nA rewarding opportunity ...  SQL_Developer
# ...

# %%
resumes_dir = "C:/Users/pcc/Downloads/Resumes-20230330T133835Z-001/Resumes/Resumes/Peoplesoft resumes"

job_role = 'Peoplesoft_DBA_Admin'

resume_data = []

for filename in os.listdir(resumes_dir):
    file_path = os.path.join(resumes_dir, filename)

    if filename.endswith('.docx'):
        document = Document(file_path)
        text = '\n'.join([paragraph.text for paragraph in document.paragraphs])
 
    elif filename.endswith('.doc'):
        document = Document(file_path)
        text = '\n'.join([paragraph.text for paragraph in document.paragraphs])

    elif filename.endswith('.pdf'):
        with open(file_path, 'rb') as f:
            pdf_reader = PyPDF2.PdfReader(f)
            text = ''
            for page_num in range(len(pdf_reader.pages)):
                page = pdf_reader.pages[page_num]
                text += page.extract_text()

    resume_data.append({'text': text, 'job_role': job_role})

people_soft_dba = pd.DataFrame(resume_data)

people_soft_dba
# Out:
#                                                  text              job_role
# 0     Anubhav Kumar Singh\t\t\n\n  To work in a gl...  Peoplesoft_DBA_Admin
# 1   \n\n\n\n\n\n\t\n\nProfile Summary:\t\t\t\t\t\t...  Peoplesoft_DBA_Admin
# 2   PeopleSoft Database Administrator\n           ...  Peoplesoft_DBA_Admin
# 3   Murali\n\nExperience Summary \n\nI have 6 year...  Peoplesoft_DBA_Admin
# 4   Priyanka Ramadoss\n61/46, MountPleasant, \nCoo...  Peoplesoft_DBA_Admin
# 5   \n\n\n\n\n\n\n\n\n\n\n\n\n\nPROFILE SUMMARY\n\...  Peoplesoft_DBA_Admin
# 6   PEOPLESOFT Administrator\n\n\nSRINIVAS.K \t\t\...  Peoplesoft_DBA_Admin
# 7    PeopleSoft Admin\nVARKALA VIKAS\n\nCareer Obj...  Peoplesoft_DBA_Admin
# 8   Vinod Akkala                                  ...  Peoplesoft_DBA_Admin
# 9    PeopleSoft Admin/PeopleSoft DBA\n\nGanesh All...  Peoplesoft_DBA_Admin
# 10  PeopleSoft Administration\n \nVivekanand Sayan...  Peoplesoft_DBA_Admin
# ...

# %%
resumes_dir = "C:/Users/pcc/Downloads/Resumes-20230330T133835Z-001/Resumes/Resumes/workday resumes"

job_role = "Consultant"

resume_data = []

for filename in os.listdir(resumes_dir):
    file_path = os.path.join(resumes_dir, filename)
    
    if filename.endswith('.docx'):
        document = Document(file_path)
        text = '\n'.join([paragraph.text for paragraph in document.paragraphs])

    elif filename.endswith('.doc'):
        document = Document(file_path)
        text = '\n'.join([paragraph.text for paragraph in document.paragraphs])

    elif filename.endswith('.pdf'):
        with open(file_path, 'rb') as f:
            pdf_reader = PyPDF2.PdfReader(f)
            text = ''
            for page_num in range(len(pdf_reader.pages)):
                page = pdf_reader.pages[page_num]
                text += page.extract_text()

    resume_data.append({'text': text, 'job_role': job_role})

workday_consultant = pd.DataFrame(resume_data)

workday_consultant
# Out:
#                                                  text    job_role
# 0   Chinna Subbarayudu M\nDOB: 06th March 1994\nNa...  Consultant
# 1   \t\n\n\nName         : Gopi Krishna Reddy\n\t\...  Consultant
# 2   Hari Krishna M\n\n\nSummary:\nA result oriente...  Consultant
# 3   Harikrishna Akula                             ...  Consultant
# 4   HIMA.MENDU\n  \n\nCareer Objective\nTo continu...  Consultant
# 5                                         \n      ...  Consultant
# 6   \t\t\t\t\t\t\tName:\tJ. Sumanth Royal.\n\t\nPR...  Consultant
# 7   \n\nJYOTI VERMA\t\t\t\t\t\n\n\n\n3 years of Ex...  Consultant
# 8   \t\t\t\t\tMadeeswar A\n\t\n\t\nPROFILE SUMMARY...  Consultant
# 9   \n\nMooraboyina Guravaiah\nWorkday Integration...  Consultant
# 10  Name\t: Naresh Babu Cherukuri\n\nObjective:\nT...  Consultant
# 11  VENKATA SAIKRISHNA\n Workday Consultant\n\n\nP...  Consultant
# 12  \n\n\n3.3 years of IT experience as Workday HC...  Consultant
# ...

# %%
# Concate pandas dataframe 
df=pd.concat([people_soft_dba,sql_dev,react_dev,workday_consultant])
#Shuffle the rows 
df=df.sample(frac=1).reset_index(drop=True)
#print the shape of dataframe
print(df.shape)
# Print the first 5 rows of the DataFrame
df.head()
# Out:
# (79, 2)
#                                                 text              job_role
# 0  PeopleSoft Administration\n \nVivekanand Sayan...  Peoplesoft_DBA_Admin
# 1  \n\nJYOTI VERMA\t\t\t\t\t\n\n\n\n3 years of Ex...            Consultant
# 2   RAJU PAVANA KUMARI\n\n\nProfessional Summary:...         SQL_Developer
# 3   \n\nCAREER OBJECTIVE\t\t\n\nPursuing Peopleso...  Peoplesoft_DBA_Admin
# 4  \tWorkday Integration Consultant\n\nName      ...            Consultant

# %%
df.to_csv(r'C:\Users\pcc\Desktop\Resume_data.csv')

# %%
df.loc[78]["text"]
# Out:
# '                                                                          \nVinay kumar .v\nWorkday Functional Consultant\n\nEXPERTISE SUMMARY\t\nHaving 4.2 years of Total Experience in as a Workday  Functional Consultant.\nKnowledge on the functional modules of Workday (Core HCM, Supervisory Organization, Delegation, Cost Center, Locations and Knowledge on Security).\nExperience in implementing Workday Functional and Integrations for various modules including HCM Core, Compensation, Time Tracking and Absence Management, Payroll, Benefits and Performance Management.\nHaving good knowledge on Security Groups: Role Based, User Based & Job Based.\nExperienced in Report Writing, Custom Reports (Simple, Advanced, Matrix and Composite), Calculated Fields, Integrations, EIB, Connectors, XML, XSLT, Workday web services, Organization Structure & Custom Objects. \nHands-on experience In Migrating the XSLT Code, Reports from Lower tenant to Sandbox and Production using Object Transporter.  \nE
# ...

# %%
[print(i) for i in df["text"]]
# Out:
# PeopleSoft Administration
#
# Vivekanand Sayana
#
# Career Objective:
#
# With my valid expertise of 7.5 years in PeopleSoft, I hope to enhance my skill set while adding value to the business, to enable implementation of solutions, which aid the company’s objectives, understanding and anticipating the needs, interests and motivations of the clients and to deliver on time, budget and to quality, delivering value through improving agility, quality and reliability
#
# Professional Summary:
#
# Over 7.5 years of experience in PeopleSoft implementation, Support, configuration, migrations, maintenance and administration of Application Server Domains, Process Scheduler Servers, Web Server Domains, PeopleTools Upgrades, Application Updates, PUM, SES and Elastic Search.
# Experience in integration activities between various PeopleSoft Financials, HRMS, EPM and FSCM environments.
# Extensively involved in resolving Performance issues.
# ...
